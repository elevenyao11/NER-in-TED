# %% [markdown]
# Named Entity extraction - Corpus to .CSV file for Amazon Mechanical Turk Annotation
# --

# %% [markdown]
# **This .ipynb notebook is used for extraction is primarily used to extract the named entities from the corpus and load it to .csv file.**

# %% [markdown]
# Import required Libraries
# --

# %%
import re
import json
import spacy
from spacy import displacy
import en_core_web_sm
nlp = en_core_web_sm.load()
from collections import defaultdict
import pandas as pd
import numpy as np

# %% [markdown]
# Variabe Declaration
# --

# %%
labels = ["PERSON", "FAC", "ORG", "GPE", "LOC", "PRODUCT", "EVENT", "WORK_OF_ART", "TIME", "LAW", "NORP"]
path = f"/Users/gurpreetbedi/Downloads/COLX_523_Group2/transcripts/en/filtered/filtered_annotated_ted_talks_en.json"
talks_id, paras_id, before, entities, labels_, after, entities_id, temp  = ([] for _ in range(8))
talks, title, talker, ents = ({} for _ in range(4))

# %% [markdown]
# Preprocess the talks
# --

# %%
def preprocess_talk(content):
    text = {}
    ents = {}
    title = content["title"]
    author = content["talker"]
    for i in range(len(content["text"])):
        text[i] = content["text"][i]["text"]
        for j in range(len(content["text"][i]["ents"])):
            ents[j] = content["text"][i]["ents"][j]
    return text, title, author, ents

# %% [markdown]
# To get the context before the entity
# --

# %%
def get_before_context(para, start):
    '''takes the paragraph and entitty start index and returns the context before the entity
    '''
    bef = []
    before_patt = re.compile("[^.]+$")
    bef_ent = before_patt.search(para[:start])
    check = bef_ent
    if check:
        bef.append(bef_ent.group(0))
    else:
        bef.append(para[:start])
    return bef

# %% [markdown]
# To get th context after the entity
# --

# %%
def get_after_context(para, end):
    '''takes the paragraph and entitty end index and returns the context after the entity
    '''    
    aft = []
    after_patt = re.compile("[^.]*")
    aft_ent = after_patt.search(para[end+1:]) 
    check = aft_ent
    if check:
        aft.append(aft_ent.group(0))
    else:
        aft.append(para[end+1:])    
    return aft

# %% [markdown]
# Grouping same labels
# --

# %%
def get_labels(label):
    '''takes the label and return similar grouped labels
    '''        
    lab = []
    if label == "FAC":
        lab.append("ORG")
    elif label == "GPE":
        lab.append("LOC")
    else:
        lab.append(label) 
    return lab

# %%
def flatten_all(df, df_cols, fill_value=''):
    '''flatten the lists csv load
    '''        
    if df_cols and not isinstance(df_cols, list):
        df_cols = [df_cols]
    idx_cols = df.columns.difference(df_cols)
    lens = df[df_cols[0]].str.len()
    if (lens > 0).all():
        return pd.DataFrame({
            col:np.repeat(df[col].values, df[df_cols[0]].str.len())
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in df_cols}).loc[:, df.columns]
    else:
        return pd.DataFrame({
            col:np.repeat(df[col].values, df[df_cols[0]].str.len())
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in df_cols}).append(df.loc[lens==0, idx_cols]).fillna(fill_value).loc[:, df.columns]

# %% [markdown]
# Create CSV from the extracted dataset
# --

# %%
def create_csv(talks_id, paras_id, entities_id, before, entities, after, labels_):
    '''takes the required fileds as argumensts and returns the pandas dataframe
    '''    
    ids = {"talk_id" : talks_id,
          "para_id" : paras_id,
          "entity_id" : entities_id,
          "before" : before,
          "entities" : entities,
          "after" : after,
          "label" : labels_}

    df = pd.DataFrame(data=ids)
    final_df = flatten_all(df, df_cols=list(df.columns))
    return final_df

# %%
with open(path) as json_file:
    contents = json.load(json_file)

num_of_talks = -1

processed_talk = {}
for i in range(len(contents[:num_of_talks])):
    talks[i], title[i], talker[i], ents[i]= preprocess_talk(contents[:num_of_talks][i])
    
assert len(talks) == len(ents), "There are missing entities, please recheck!"

for talk_id, text in talks.items():
    for para_id, para in text.items():
        entity_id, label, t_id, p_id, before_cont, after_cont, entity = ([] for _ in range(7))
        for e_id, ents_ in ents[talk_id].items():
            if ents_["label"] in labels:
                start = ents_["start"]
                end = ents_["end"]
                if ents_["text"] == para[start:end] and (ents_["text"],ents_["label"]) not in temp:
                    entity_id.append(e_id)        
                    entity.append(ents_["text"])   
                    before_cont.append(get_before_context(para, start))
                    after_cont.append(get_after_context(para, end))
                    t_id.append(talk_id)
                    p_id.append(para_id)  
                    label.append(get_labels(ents_["label"]))
                    temp.append((ents_["text"], ents_["label"]))

        if entity_id:
            entities_id.append(entity_id)
        if t_id:
            talks_id.append(t_id)
        if p_id:
            paras_id.append(p_id)
        if entity:
            entities.append(entity)            
        if before_cont:
            before.append(before_cont)
        if after_cont:
            after.append(after_cont)
        if label:
            labels_.append(label)     

assert len(talks_id) == len(paras_id) == len(entities_id) == len(before) == len(entities) == len(after) == len(labels_), "Length mismatch, please check as all should be the same!"

annotation_df = create_csv(talks_id, paras_id, entities_id, before, entities, after, labels_)

# %%
print(f"Total number of rows extracted : {annotation_df.shape[0]}")
# Out:
# Total number of rows extracted : 1550

# %% [markdown]
# Top 60 records from the dataframe
# --

# %%
annotation_df.head(60)
# Out:
#     talk_id  para_id  entity_id  \
# 0         0        0          0
# 1         0        0          1
# 2         0        0          5
# 3         0        0         16
# 4         0        0         17
# 5         1        0          1
# 6         1        0         10
# 7         1        0         11
# 8         1        0         12
# 9         1        0         13
# 10        1        0         16
# 11        1        0         17
# 12        1        0         18
# 13        1        0         21
# 14        1        0         22
# 15        1        0         23
# 16        1        0         25
# 17        1        0         26
# 18        1        0         27
# 19        3        0          1
# 20        3        0          3
# 21        3        0          5
# 22        3        0          9
# 23        3        0         10
# 24        3        0         11
# 25        3        0         16
# 26        3        0         19
# 27        4       14          5
# 28        4       14         10
# 29        4       17          2
# 30        4       17          3
# 31        4       33          1
# 32        5       17          6
# 33        5       17          7
# 34        5       17          9
# 35        5       17         10
# 36        5       17         12
# 37        5       22          4
# 38        5       22          5
# 39        5       28          1
# 40        5       29          0
# 41        6        5          6
# 42        6        5          7
# 43        6       23          3
# 44        6       34          0
# 45        6       34          1
# 46        7        0          0
# 47        7        0          1
# 48        7        0          2
# 49        7        0          7
# 50        7        0         10
# 51        7        0         11
# 52        7        0         12
# 53        7        0         13
# 54        7        0         14
# 55        7        0         15
# 56        7        0         16
# 57        7        0         17
# 58        7        0         18
# 59        7        0         19
#
#                                                before  \
# 0    Aesthetically speaking, there's a world of di...
# 1    Aesthetically speaking, there's a world of di...
# 2                                             In the
# 3    The point is that just like the second hand o...
# 4    The point is that just like the second hand o...
# 5    Which ends up being heard as the main beat is...
# 6    This is the basis of the music of Whirling De...
# 7    This is the basis of the music of Whirling De...
# 8    This is the basis of the music of Whirling De...
# 9    This is the basis of the music of Whirling De...
# 10   Now if we remember Rubin's vase and hear the ...
# 11   Now if we remember Rubin's vase and hear the ...
# 12   Now if we remember Rubin's vase and hear the ...
# 13       This rhythmic configuration is found as the
# 14   This rhythmic configuration is found as the C...
# 15   This rhythmic configuration is found as the C...
# 16   And rotating the outer circle 90 degrees coun...
# 17   And rotating the outer circle 90 degrees coun...
# 18   And rotating the outer circle 90 degrees coun...
# 19   So how does practice or repetition affect the...
# 20
# 21   While we don't yet have a magic number, we do...
# 22   On average, those students were able to stay ...
# 23            Laptops, smartphones, and particularly
# 24   Studies have shown that many top athletes, mu...
# 25
# 26   In the meantime, effective practice is the be...
# 27   I do all of this with drafting templates, wit...
# 28   I do all of this with drafting templates, wit...
# 29                                        I took the
# 30   I took the Copenhagen subway map and I rename...
# 31              And I'll perform just an excerpt of "
# 32           Actually, he is quite well known in the
# 33                                      And I'll let
# 34                                     So, Adam is a
# 35                                        student at
# 36                                      And Adam and
# 37   In fact, this is the score for Dan's piece, c...
# 38   So he can use his infrared tracker to go dire...
# 39              TM: OK, now Dan will play his piece "
# 40                                               TM:
# 41   How did this piece of 18th century Austrian a...
# 42   How did this piece of 18th century Austrian a...
# 43   A piece like Beethoven's Fifth basically witn...
# 44                                    And of course,
# 45      And of course, the New World Symphony led to
# 46                                       The ancient
# 47                     The ancient Greek philosopher
# 48                                           In his "
# 49               One day, they angered the gods, and
# 50   Love is the longing to find a soulmate who'll...
# 51                                 Much, much later,
# 52              Much, much later, German philosopher
# 53                                      According to
# 54              According to the Nobel Prize-winning
# 55   According to the Nobel Prize-winning British ...
# 56
# 57
# 58       Siddhārtha Gautama, who became known as the
# 59   Siddhārtha Gautama, who became known as the B...
#
#                          entities  \
# 0                       Beethoven
# 1                   Justin Bieber
# 2                         Western
# 3                      one minute
# 4                   sixty seconds
# 5                           Rubin
# 6                  Latin American
# 7                          Joropo
# 8                            Bach
# 9                        Chaconne
# 10                      Chacarera
# 11                        Quechua
# 12                        Persian
# 13                          Cuban
# 14                   Puerto Rican
# 15              Northern Romanian
# 16                 Middle Eastern
# 17                      Brazilian
# 18                    Argentinian
# 19                         myelin
# 20                         Myelin
# 21                          hours
# 22               only six minutes
# 23                       Facebook
# 24                    50-60 hours
# 25                        Group A
# 26                    new heights
# 27  the Cantor Arts Center Museum
# 28                           noon
# 29                     Copenhagen
# 30          minutes past the hour
# 31                        Aphasia
# 32                         Boston
# 33                           Adam
# 34                          Ph.D.
# 35                            MIT
# 36                            Dan
# 37                     Hyperscore
# 38                     Hyperscore
# 39         My Eagle Song" for you
# 40                          Bravo
# 41                       New York
# 42                         Mozart
# 43                 a half an hour
# 44         the New World Symphony
# 45           the YouTube Symphony
# 46                          Greek
# 47                          Plato
# 48                      Symposium
# 49                           Zeus
# 50                          Plato
# 51                         German
# 52            Arthur Schopenhauer
# 53                the Nobel Prize
# 54                        British
# 55               Bertrand Russell
# 56                           Love
# 57             Siddhārtha Gautama
# 58                         Buddha
# 59                        Russell
#
#                                                 after        label
# 0   and Justin Bieber, but both artists have used ...       PERSON
# 1    but both artists have used the same building ...       PERSON
# 2   music tradition, pitches are named after the f...         NORP
# 3   into sixty seconds, with each second just as l...         TIME
# 4    with each second just as long as every other ...         TIME
# 5   s vase, can be reversed depending on cultural ...       PERSON
# 6   rhythms, such as Joropo, and even Bach's famou...         NORP
# 7                     and even Bach's famous Chaconne         NORP
# 8                                   s famous Chaconne       PERSON
# 9    Now if we remember Rubin's vase and hear the ...       PERSON
# 10                and Quechua, Persian music and more          ORG
# 11                             Persian music and more          LOC
# 12                                     music and more         NORP
# 13  cinquillo, in the Puerto Rican bomba, and in N...         NORP
# 14              bomba, and in Northern Romanian music         NORP
# 15                                              music          LOC
# 16  music, as well as Brazilian choro, and Argenti...          LOC
# 17                       choro, and Argentinian tango         NORP
# 18                                              tango         NORP
# 19   And it's this myelin covering, or sheath, tha...          ORG
# 20      is similar to insulation on electrical cables          ORG
# 21                                        of practice         TIME
# 22                                          at a time         TIME
# 23                 were the root of most distractions          ORG
# 24      per week on activities related to their craft         TIME
# 25  physically practiced one-handed free throws wh...       PERSON
# 26                       and maximizing our potential          LOC
# 27  lobby balcony, and it appeared for one year in...          ORG
# 28  til one, and only during that time, various pe...         TIME
# 29  subway map and I renamed all the stations to a...          ORG
# 30                                                            TIME
# 31                                       for you here  WORK_OF_ART
# 32  area — mentors people at the hospital and chil...          LOC
# 33                                           tell you       PERSON
# 34  student at MIT, an expert in music technology ...  WORK_OF_ART
# 35         an expert in music technology and medicine          ORG
# 36                    have become close collaborators       PERSON
# 37   So he can use his infrared tracker to go dire...          LOC
# 38   He's incredibly fast at it, too, faster than ...          ORG
# 39                                         (Applause)  WORK_OF_ART
# 40                                         (Applause)       PERSON
# 41  kid? How was that passed on? How did he get to...          LOC
# 42                                                          PERSON
# 43   step by exacting step of his route, to the mo...         TIME
# 44  led to the YouTube Symphony and projects on th...          ORG
# 45  and projects on the internet that reach out to...          ORG
# 46  philosopher Plato explored the idea that we lo...         NORP
# 47  explored the idea that we love in order to bec...          ORG
# 48  , he wrote about a dinner party, at which Aris...  WORK_OF_ART
# 49                             sliced them all in two       PERSON
# 50   believed a drunken comedian would say at a party       PERSON
# 51  philosopher Arthur Schopenhauer maintained tha...         NORP
# 52  maintained that love based in sexual desire wa...       PERSON
# 53  winning British philosopher Bertrand Russell, ...  WORK_OF_ART
# 54  philosopher Bertrand Russell, we love in order...         NORP
# 55   we love in order to quench our physical and p...       PERSON
# 56  s delight, intimacy, and warmth helps us overc...       PERSON
# 57   who became known as the Buddha, or the Enligh...       PERSON
# 58   or the Enlightened One, probably would have h...       PERSON
# 59   Buddha proposed that we love because we are t...       PERSON

# %% [markdown]
# Writing Datafram to .csv file for Amazon Mechanical Turk
# --

# %%
annotation_df.to_csv("/Users/gurpreetbedi/Downloads/COLX_523_Group2/transcripts/en/annotated/Annotation.csv", index=False)

# %% [markdown]
# Testing for Unique Entity-Label pairs using SpaCy Display render feature
# --

# %% [markdown]
# **Note: Extract Named entity is being used from [process_corpus.ipynb](https://github.ubc.ca/iameleve/COLX_523_Group2/blob/master/src/process_corpus.ipynb) for testing purposes.**

# %%
def extract_named_entity(talk, title=None, talker=None):
    ne_lex = {}
    doc = nlp(talk)
    ents = []
    ne_lex["text"] = talk            
    for ent in doc.ents:
        if ent.label_ in labels:
            ent_lex = {}
            ent_lex["start"] = ent.start_char
            ent_lex["end"] = ent.end_char
            ent_lex["text"] = ent.text
            ent_lex["label"] = ent.label_
            ents.append(ent_lex)
    ne_lex["ents"] = ents
    ne_lex["title"] = title
    ne_lex["talker"] = talker

    return ne_lex

# %% [markdown]
# Below are the test cases
# --

# %%
dict_ = extract_named_entity(talks[11][0])
set([(ents["text"], ents["label"]) for ents in dict_["ents"]])
# Out:
# {("B. It's", 'PERSON'),
#  ('Christian Rudder', 'PERSON'),
#  ('OkCupid', 'GPE'),
#  ('OkCupid', 'ORG'),
#  ('OkCupid', 'PERSON'),
#  ('the United States', 'GPE')}

# %%
annotation_df.query("talk_id==11").query("para_id==0")[["entities", "label"]]
# Out:
#               entities   label
# 109   Christian Rudder  PERSON
# 110            OkCupid     LOC
# 111  the United States     LOC
# 112            OkCupid     ORG
# 113            OkCupid  PERSON
# 114            B. It's  PERSON

# %%
dict_ = extract_named_entity(talks[44][14])
set([(ents["text"], ents["label"]) for ents in dict_["ents"]])
# Out:
# {('Chiho', 'PERSON'),
#  ('Mick Jagger', 'PERSON'),
#  ('Nirvana', 'PERSON'),
#  ('TED', 'ORG')}

# %%
annotation_df.query("talk_id==44").query("para_id==14")[["entities", "label"]]
# Out:
#         entities   label
# 289  Mick Jagger  PERSON
# 290        Chiho  PERSON
# 291          TED     ORG

# %%
dict_ = extract_named_entity(talks[1][0])
set([(ents["text"], ents["label"]) for ents in dict_["ents"]])
# Out:
# {('Argentinian', 'NORP'),
#  ('Bach', 'PERSON'),
#  ('Brazilian', 'NORP'),
#  ('Chacarera', 'ORG'),
#  ('Chaconne', 'PERSON'),
#  ('Cuban', 'NORP'),
#  ('Joropo', 'NORP'),
#  ('Latin American', 'NORP'),
#  ('Middle Eastern', 'LOC'),
#  ('Northern Romanian', 'LOC'),
#  ('Persian', 'NORP'),
#  ('Puerto Rican', 'NORP'),
#  ('Quechua', 'GPE'),
#  ('Rubin', 'PERSON')}

# %%
annotation_df.query("talk_id==1").query("para_id==0")[["entities", "label"]]
# Out:
#              entities   label
# 5               Rubin  PERSON
# 6      Latin American    NORP
# 7              Joropo    NORP
# 8                Bach  PERSON
# 9            Chaconne  PERSON
# 10          Chacarera     ORG
# 11            Quechua     LOC
# 12            Persian    NORP
# 13              Cuban    NORP
# 14       Puerto Rican    NORP
# 15  Northern Romanian     LOC
# 16     Middle Eastern     LOC
# 17          Brazilian    NORP
# 18        Argentinian    NORP

# %% [markdown]
# **So, the data is matching to the the filtered data set!!**
